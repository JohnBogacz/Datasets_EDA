# %% [markdown]
# # Preprocess Pipeline

# %%
import os
import gc
import warnings
import json

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import statsmodels as sm
from prettytable import PrettyTable

# %%
from sklearn.preprocessing import (
    OrdinalEncoder,
    StandardScaler,
    RobustScaler,
    OneHotEncoder,
)
from sklearn.preprocessing import TargetEncoder
from sklearn.decomposition import (
    PCA,
    SparsePCA
)
from sklearn.pipeline import (
    Pipeline,
    make_pipeline,
)
from sklearn.compose import (
    ColumnTransformer
)
from sklearn.model_selection import (
    train_test_split
)

# %%
PATH = os.getcwd()
PATH = PATH.split('/')[:-2]
PATH = ''.join([str(folder + '/') for folder in PATH])
print(PATH)
# Out:
# /Users/school/Documents/repositories/Datasets_EDA/src/Allstate Claims Severity/

# %%
train_df = pd.read_csv(
    filepath_or_buffer= os.path.join(PATH, 'code', 'v2', 'train_v2.csv')
)

# %%
y = train_df['loss']
X = train_df.drop(
    columns= ['id','loss'],
    axis= 0
)

# %%
print(y)
# Out:
# 0         2213.18
# 1         1283.60
# 2         3005.09
# 3          939.85
# 4         2763.85
#            ...
# 194587    1198.62
# 194588    1108.34
# 194589    5762.64
# 194590    1562.87
# 194591    4751.72
# Name: loss, Length: 194592, dtype: float64

# %%
print(X)
# Out:
#        cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10  ...     cont5  \
# 0         A    B    A    B    A    A    A    A    B     A  ...  0.310061
# 1         A    B    A    A    A    A    A    A    B     B  ...  0.885834
# 2         A    B    A    A    B    A    A    A    B     B  ...  0.397069
# 3         B    B    A    B    A    A    A    A    B     A  ...  0.422268
# 4         A    B    A    B    A    A    A    A    B     B  ...  0.704268
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...       ...
# 194587    A    B    A    A    A    A    A    A    B     A  ...  0.939556
# 194588    A    A    A    A    A    B    A    A    A     A  ...  0.704268
# 194589    A    B    A    A    A    A    A    B    B     A  ...  0.482436
# 194590    A    B    A    A    A    A    A    A    B     B  ...  0.340543
# 194591    B    A    A    B    A    A    A    A    A     A  ...  0.281143
#
#            cont6     cont7    cont8    cont9   cont10    cont11    cont12  \
# 0       0.718367  0.335060  0.30260  0.67135  0.83510  0.569745  0.594646
# 1       0.438917  0.436585  0.60087  0.35127  0.43919  0.338312  0.366307
# 2       0.289648  0.315545  0.27320  0.26076  0.32446  0.381398  0.373424
# 3       0.440945  0.391128  0.31796  0.32128  0.44467  0.327915  0.321570
# 4       0.178193  0.247408  0.24564  0.22089  0.21230  0.204687  0.202213
# ...          ...       ...      ...      ...      ...       ...       ...
# 194587  0.242437  0.289949  0.24564  0.30859  0.32935  0.223038  0.220003
# 194588  0.334270  0.382000  0.63475  0.40455  0.47779  0.307628  0.301921
# 194589  0.345883  0.370534  0.24564  0.45808  0.47779  0.445614  0.443374
# 194590  0.704364  0.562866  0.34987  0.44767  0.53881  0.863052  0.852865
# 194591  0.844563  0.533048  0.97123  0.93383  0.83814  0.932195  0.946432
#
#           cont13    cont14
# 0       0.822493  0.714843
# 1       0.611431  0.304496
# 2       0.195709  0.774425
# 3       0.605077  0.602642
# 4       0.246011  0.432606
# ...          ...       ...
# 194587  0.333292  0.208216
# 194588  0.318646  0.305872
# 194589  0.339244  0.503888
# 194590  0.654753  0.721707
# 194591  0.810511  0.721460
#
# [194592 rows x 130 columns]

# %%
gc.collect()
# Out:
# 0

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size= 0.25,
    random_state= 4095,
    
)
del X, y

# %%
print(X_train)
print(X_train.shape)
# Out:
#        cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10  ...     cont5  \
# 133017    A    B    A    A    B    A    A    A    B     B  ...  0.845727
# 8498      A    B    A    B    A    A    A    A    B     A  ...  0.858841
# 38546     A    A    A    B    B    A    A    A    A     A  ...  0.288217
# 10917     B    A    A    B    A    A    A    A    A     A  ...  0.281143
# 83256     A    A    A    A    A    B    A    A    A     A  ...  0.281143
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...       ...
# 100201    A    A    A    A    A    A    A    A    A     A  ...  0.783230
# 24465     A    B    A    A    A    A    A    A    B     A  ...  0.397069
# 35429     B    A    A    B    A    A    A    A    A     A  ...  0.499798
# 26602     A    A    A    B    A    A    A    A    A     A  ...  0.783230
# 158976    B    A    A    A    A    B    A    A    A     A  ...  0.317541
#
#            cont6     cont7    cont8    cont9   cont10    cont11    cont12  \
# 133017  0.805849  0.638454  0.66201  0.65824  0.67065  0.751690  0.758883
# 8498    0.349350  0.362171  0.39455  0.38249  0.35434  0.260140  0.264760
# 38546   0.204165  0.348605  0.23688  0.22234  0.19782  0.348867  0.341872
# 10917   0.331398  0.361715  0.56600  0.39648  0.32935  0.245410  0.255941
# 83256   0.484775  0.729795  0.35533  0.40657  0.40666  0.468839  0.458493
# ...          ...       ...      ...      ...      ...       ...       ...
# 100201  0.373500  0.381883  0.36083  0.44352  0.45017  0.338312  0.366307
# 24465   0.966438  0.640047  0.58934  0.97621  0.83510  0.895938  0.887214
# 35429   0.314683  0.370419  0.58354  0.46226  0.38016  0.341813  0.352251
# 26602   0.331919  0.336160  0.36083  0.39849  0.39599  0.297750  0.301921
# 158976  0.464835  0.800337  0.70839  0.43111  0.36974  0.569745  0.557380
#
#           cont13    cont14
# 133017  0.743962  0.660295
# 8498    0.327393  0.209840
# 38546   0.268941  0.230744
# 10917   0.295948  0.506150
# 83256   0.304350  0.741741
# ...          ...       ...
# 100201  0.339244  0.383675
# 24465   0.906079  0.686929
# 35429   0.339244  0.692875
# 26602   0.351299  0.349425
# 158976  0.256038  0.208243
#
# [145944 rows x 130 columns]
# (145944, 130)

# %%
CAT_X = [str('cat' + str(i)) for i in range(1, 117, 1)]
CONT_X = [str('cont' + str(i)) for i in range(1, 15, 1)]

# %% [markdown]
# ### B.2 Pipeline

# %% [markdown]
# #### B.2.1 Continuous

# %%
print('Before')
print(X_train[CONT_X])
# Out:
# Before
#            cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 133017  0.626630  0.785784  0.762059  0.873871  0.845727  0.805849  0.638454
# 8498    0.462786  0.620805  0.484196  0.833240  0.858841  0.349350  0.362171
# 38546   0.067520  0.620805  0.944251  0.189137  0.288217  0.204165  0.348605
# 10917   0.493164  0.422197  0.462347  0.833240  0.281143  0.331398  0.361715
# 83256   0.351358  0.737068  0.777587  0.182950  0.281143  0.484775  0.729795
# ...          ...       ...       ...       ...       ...       ...       ...
# 100201  0.475784  0.785784  0.592681  0.614134  0.783230  0.373500  0.381883
# 24465   0.961159  0.620805  0.246911  0.821574  0.397069  0.966438  0.640047
# 35429   0.520698  0.422197  0.549770  0.452887  0.499798  0.314683  0.370419
# 26602   0.475784  0.422197  0.484196  0.534409  0.783230  0.331919  0.336160
# 158976  0.372785  0.785784  0.692825  0.284048  0.317541  0.464835  0.800337
#
#           cont8    cont9   cont10    cont11    cont12    cont13    cont14
# 133017  0.66201  0.65824  0.67065  0.751690  0.758883  0.743962  0.660295
# 8498    0.39455  0.38249  0.35434  0.260140  0.264760  0.327393  0.209840
# 38546   0.23688  0.22234  0.19782  0.348867  0.341872  0.268941  0.230744
# 10917   0.56600  0.39648  0.32935  0.245410  0.255941  0.295948  0.506150
# 83256   0.35533  0.40657  0.40666  0.468839  0.458493  0.304350  0.741741
# ...         ...      ...      ...       ...       ...       ...       ...
# 100201  0.36083  0.44352  0.45017  0.338312  0.366307  0.339244  0.383675
# 24465   0.58934  0.97621  0.83510  0.895938  0.887214  0.906079  0.686929
# 35429   0.58354  0.46226  0.38016  0.341813  0.352251  0.339244  0.692875
# 26602   0.36083  0.39849  0.39599  0.297750  0.301921  0.351299  0.349425
# 158976  0.70839  0.43111  0.36974  0.569745  0.557380  0.256038  0.208243
#
# [145944 rows x 14 columns]

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html#sklearn.pipeline.Pipeline
cont_pipeline= Pipeline(
    steps= [
        (
            'scaler',
            RobustScaler( # https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html#sklearn.preprocessing.RobustScaler
                with_centering= True,
                with_scaling= True,
                # quantile_range= ,
                unit_variance= True
            )
        ),
        (
            'pca',
            PCA( # https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html#sklearn.decomposition.PCA
                n_components= 'mle',
                # copy: bool = True,
                # whiten: bool = False,
                svd_solver= "auto",
                # tol: Float = 0,
                # iterated_power: Int | Literal['auto'] = "auto",
                # n_oversamples: Int = 10,
                # power_iteration_normalizer: Literal['auto', 'QR', 'LU', 'none'] = "auto",
                random_state= 4095
            )
        )
    ]
)

# https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html#sklearn.compose.ColumnTransformer
cont_preprocessor = ColumnTransformer(
    transformers=[
        ('continuous', cont_pipeline, CONT_X),
    ])

# %%
cont_preprocessor
# Out:
# ColumnTransformer(transformers=[('continuous',
#                                  Pipeline(steps=[('scaler',
#                                                   RobustScaler(unit_variance=True)),
#                                                  ('pca',
#                                                   PCA(n_components='mle',
#                                                       random_state=4095))]),
#                                  ['cont1', 'cont2', 'cont3', 'cont4', 'cont5',
#                                   'cont6', 'cont7', 'cont8', 'cont9', 'cont10',
#                                   'cont11', 'cont12', 'cont13', 'cont14'])])

# %%
after_data = cont_preprocessor.fit_transform(X_train)
after_data = pd.DataFrame(
    data= after_data,
)
print('After')
print(after_data)
del after_data
# Out:
# After
#               0         1         2         3         4         5         6   \
# 0       2.704851  0.725858  2.392243 -0.253668  0.721206  0.400600  0.557179
# 1      -1.656761 -1.206162  1.371314 -0.563968  0.833353 -1.032388  0.056500
# 2      -3.982972  1.829617  0.002258  0.214165 -0.753605 -0.491473 -0.638822
# 3      -1.416029 -1.425447  0.209302  1.230888  0.432375 -0.035363 -0.904777
# 4      -0.981403  2.445807 -0.266940  0.221293 -0.388720  0.890537 -0.338565
# ...          ...       ...       ...       ...       ...       ...       ...
# 145939 -1.183862 -0.207105  1.412361 -1.038941  0.240196 -0.291685 -0.257080
# 145940  5.608953 -0.646191  0.235439 -0.385660  0.009462  0.540336 -0.630884
# 145941 -1.123915 -0.625371  0.067032  0.180900  0.250826  0.749077 -0.348201
# 145942 -1.636377 -0.933232  0.217480 -0.853192  0.586777 -0.481148  0.198168
# 145943 -0.346881  2.256650  0.548880  1.165106 -0.292567 -0.793239 -0.324340
#
#               7         8         9         10        11        12
# 0      -0.180780 -0.283682 -0.453591  0.842136 -0.090816  0.235977
# 1      -0.468089  0.486950 -0.276077  0.443633 -0.183724  0.044902
# 2       0.274247 -0.697206  0.056022  0.453133  0.332069  0.177242
# 3      -0.329948  0.181784 -0.469871  0.143697 -0.354548  0.025450
# 4      -0.076733  0.827721 -0.427635  0.001985  0.080535  0.212372
# ...          ...       ...       ...       ...       ...       ...
# 145939 -0.388465  0.387831 -0.136822  0.133966  0.010495  0.048833
# 145940 -0.508414  0.130759  0.357594  0.734174 -0.105397  0.088805
# 145941  0.700039  0.074585 -0.117690 -0.302648 -0.166288 -0.103185
# 145942  0.155975  0.041497 -0.147873  0.027636 -0.114071 -0.016615
# 145943  0.653108  1.267783  0.098376 -0.450485  0.160024  0.062849
#
# [145944 rows x 13 columns]

# %% [markdown]
# #### B.2.1 Categorical

# %%
print("Before")
print(X_train[CAT_X])
# Out:
# Before
#        cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10  ... cat107 cat108  \
# 133017    A    B    A    A    B    A    A    A    B     B  ...      J      K
# 8498      A    B    A    B    A    A    A    A    B     A  ...      F      B
# 38546     A    A    A    B    B    A    A    A    A     A  ...      K      A
# 10917     B    A    A    B    A    A    A    A    A     A  ...      F      B
# 83256     A    A    A    A    A    B    A    A    A     A  ...      G      D
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...    ...    ...
# 100201    A    A    A    A    A    A    A    A    A     A  ...      F      B
# 24465     A    B    A    A    A    A    A    A    B     A  ...      H      G
# 35429     B    A    A    B    A    A    A    A    A     A  ...      F      B
# 26602     A    A    A    B    A    A    A    A    A     A  ...      G      B
# 158976    B    A    A    A    A    B    A    A    A     A  ...      F      D
#
#        cat109 cat110 cat111 cat112 cat113 cat114 cat115 cat116
# 133017     BI     CO      A     AC      S      A      O     HQ
# 8498       BI     CL      C      G      K      A      K     DC
# 38546      BI     EE      I     AH     AV      A      L     CG
# 10917      AB      C      C      W      K      A      K     DC
# 83256      BI     CL      A      F     AN      E      K     GI
# ...       ...    ...    ...    ...    ...    ...    ...    ...
# 100201     BI     CS      A      J     BM      A      K     DP
# 24465      BI     DW      A      D      Y      A      Q     JX
# 35429       G     AI      E      D     AX      A      K     DP
# 26602      BI      V      C     AI     BM      A      K     DJ
# 158976     BI     CS      A      G      H      E      J     GS
#
# [145944 rows x 116 columns]

# %%
# CAT_X = ['cat1', 'cat2', 'cat3']

# %%
# v1
from matplotlib import category


cat_pipeline= Pipeline(
    steps= [
        (
            'One Hot Encoder',
            OneHotEncoder( # https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html
                # categories: Sequence[ArrayLike] | Literal['auto'] = "auto",
                # drop= CAT_X,
                # sparse: str | bool = "deprecated",
                # sparse_output: bool = True,
                # dtype: ... = ...,
                # handle_unknown: Literal['error', 'ignore', 'infrequent_if_exist'] = "error",
                # min_frequency: float | int | None = None,
                # max_categories: Int | None = None
            ),
        ),
    ]
)

# v2
cat_pipeline= Pipeline(
    steps= [
        (
            'target',
            TargetEncoder( # https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.TargetEncoder.html
                categories= "auto",
                target_type= 'continuous',
                cv= 5,
                shuffle= True,
                random_state= 4095
            )
        )
    ]
)


cat_preprocessor = ColumnTransformer(
    transformers=[
        ('categorical', cat_pipeline, CAT_X),
    ])

# %%
cat_preprocessor
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('target',
#                                                   TargetEncoder(random_state=4095,
#                                                                 target_type='continuous'))]),
#                                  ['cat1', 'cat2', 'cat3', 'cat4', 'cat5',
#                                   'cat6', 'cat7', 'cat8', 'cat9', 'cat10',
#                                   'cat11', 'cat12', 'cat13', 'cat14', 'cat15',
#                                   'cat16', 'cat17', 'cat18', 'cat19', 'cat20',
#                                   'cat21', 'cat22', 'cat23', 'cat24', 'cat25',
#                                   'cat26', 'cat27', 'cat28', 'cat29', 'cat30', ...])])

# %%
after_data = cat_preprocessor.fit_transform(X_train, y_train)
after_data = pd.DataFrame(
    data= after_data,
)
print('After')
print(after_data)
del after_data
# Out:
# After
#                 0            1            2            3            4    \
# 0       3400.726290  3790.325086  2901.265857  2827.047257  3462.210643
# 1       3405.193546  3801.333089  2905.191945  3485.199088  2817.362924
# 2       3400.726290  2456.145293  2901.265857  3475.385958  3462.210643
# 3       1916.708036  2452.696878  2900.580188  3500.463069  2802.788523
# 4       3400.726290  2456.145293  2901.265857  2827.047257  2807.412150
# ...             ...          ...          ...          ...          ...
# 145939  3405.193546  2457.803096  2905.191945  2829.609138  2817.362924
# 145940  3400.726290  3790.325086  2901.265857  2827.047257  2807.412150
# 145941  1923.390033  2455.811652  2907.987372  3487.302572  2815.878058
# 145942  3400.726290  2456.145293  2901.265857  3475.385958  2807.412150
# 145943  1916.708036  2452.696878  2900.580188  2821.286150  2802.788523
#
#                 5            6            7            8            9    ...  \
# 0       3257.710949  2906.833066  2969.056440  3820.668911  4956.120499  ...
# 1       3261.523032  2909.592543  2975.994062  3825.879211  2690.750428  ...
# 2       3257.710949  2906.833066  2969.056440  2511.685837  2693.443613  ...
# 3       3262.044136  2908.727215  2972.260335  2509.887268  2692.902991  ...
# 4       2509.068267  2906.833066  2969.056440  2511.685837  2693.443613  ...
# ...             ...          ...          ...          ...          ...  ...
# 145939  3261.523032  2909.592543  2975.994062  2516.623677  2690.750428  ...
# 145940  3257.710949  2906.833066  2969.056440  3820.668911  2693.443613  ...
# 145941  3266.797645  2915.765503  2978.033460  2512.845033  2696.758729  ...
# 145942  3257.710949  2906.833066  2969.056440  2511.685837  2693.443613  ...
# 145943  2511.951624  2908.727215  2972.260335  2509.887268  2692.902991  ...
#
#                 106          107          108          109          110  \
# 0       3073.624139  2922.460763  3141.754885  3112.979409  2827.047257
# 1       3062.491899  2828.801781  3149.104056  3547.122987  3097.077118
# 2       2933.609822  2958.149073  3141.754885  3443.812314  4581.523865
# 3       3087.987890  2841.040764  2602.039166  2445.070005  3112.396103
# 4       3136.462039  3740.353365  3141.754885  3521.479036  2827.047257
# ...             ...          ...          ...          ...          ...
# 145939  3062.491899  2828.801781  3149.104056  3017.501892  2829.609138
# 145940  3096.246551  3096.168040  3141.754885  2645.833007  2827.047257
# 145941  3080.197440  2829.886764  2850.842851  2807.345652  3502.501091
# 145942  3136.462039  2822.925737  3141.754885  2641.974161  3083.503479
# 145943  3087.987890  3717.064688  3148.157184  3018.692928  2821.286150
#
#                 111          112          113          114          115
# 0       2715.118661  2732.948119  3257.710949  2972.874846  3278.180457
# 1       3188.100467  2772.445202  3261.523032  2996.512262  2482.692642
# 2       3452.400315  3743.586222  3257.710949  3040.013047  3893.927659
# 3       3298.458185  2780.695747  3262.044136  3021.129539  2485.636590
# 4       2928.670305  3468.953878  2074.332906  3001.583903  3272.847195
# ...             ...          ...          ...          ...          ...
# 145939  2821.878804  2892.110835  3261.523032  2996.512262  3092.569537
# 145940  2865.629379  3015.057995  3257.710949  3075.580008  4044.443097
# 145941  2905.351807  3076.068075  3266.797645  3009.251160  3096.998251
# 145942  2396.651273  2880.423392  3257.710949  3001.583903  2895.835880
# 145943  3193.171080  3956.837951  2075.850285  3148.964892  3036.777977
#
# [145944 rows x 116 columns]

# %% [markdown]
# ### B.3 Combine Pipeline & Transform '*X_test*'

# %%
final_pipeline = ColumnTransformer(
    transformers=[
        ('categorical', cat_pipeline, CAT_X),
        ('continuous', cont_pipeline, CONT_X)
    ])
print(final_pipeline)
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('target',
#                                                   TargetEncoder(random_state=4095,
#                                                                 target_type='continuous'))]),
#                                  ['cat1', 'cat2', 'cat3', 'cat4', 'cat5',
#                                   'cat6', 'cat7', 'cat8', 'cat9', 'cat10',
#                                   'cat11', 'cat12', 'cat13', 'cat14', 'cat15',
#                                   'cat16', 'cat17', 'cat18', 'cat19', 'cat20',
#                                   'cat21', 'cat22', 'cat23', 'cat24', 'cat25',
#                                   'cat26', 'cat27', 'cat28', 'cat29', 'cat30', ...]),
#                                 ('continuous',
#                                  Pipeline(steps=[('scaler',
#                                                   RobustScaler(unit_variance=True)),
#                                                  ('pca',
#                                                   PCA(n_components='mle',
#                                                       random_state=4095))]),
#                                  ['cont1', 'cont2', 'cont3', 'cont4', 'cont5',
#                                   'cont6', 'cont7', 'cont8', 'cont9', 'cont10',
#                                   'cont11', 'cont12', 'cont13', 'cont14'])])

# %%
final_pipeline
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('target',
#                                                   TargetEncoder(random_state=4095,
#                                                                 target_type='continuous'))]),
#                                  ['cat1', 'cat2', 'cat3', 'cat4', 'cat5',
#                                   'cat6', 'cat7', 'cat8', 'cat9', 'cat10',
#                                   'cat11', 'cat12', 'cat13', 'cat14', 'cat15',
#                                   'cat16', 'cat17', 'cat18', 'cat19', 'cat20',
#                                   'cat21', 'cat22', 'cat23', 'cat24', 'cat25',
#                                   'cat26', 'cat27', 'cat28', 'cat29', 'cat30', ...]),
#                                 ('continuous',
#                                  Pipeline(steps=[('scaler',
#                                                   RobustScaler(unit_variance=True)),
#                                                  ('pca',
#                                                   PCA(n_components='mle',
#                                                       random_state=4095))]),
#                                  ['cont1', 'cont2', 'cont3', 'cont4', 'cont5',
#                                   'cont6', 'cont7', 'cont8', 'cont9', 'cont10',
#                                   'cont11', 'cont12', 'cont13', 'cont14'])])

# %%
print('before')
print(X_train)
# Out:
# before
#        cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10  ...     cont5  \
# 133017    A    B    A    A    B    A    A    A    B     B  ...  0.845727
# 8498      A    B    A    B    A    A    A    A    B     A  ...  0.858841
# 38546     A    A    A    B    B    A    A    A    A     A  ...  0.288217
# 10917     B    A    A    B    A    A    A    A    A     A  ...  0.281143
# 83256     A    A    A    A    A    B    A    A    A     A  ...  0.281143
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...       ...
# 100201    A    A    A    A    A    A    A    A    A     A  ...  0.783230
# 24465     A    B    A    A    A    A    A    A    B     A  ...  0.397069
# 35429     B    A    A    B    A    A    A    A    A     A  ...  0.499798
# 26602     A    A    A    B    A    A    A    A    A     A  ...  0.783230
# 158976    B    A    A    A    A    B    A    A    A     A  ...  0.317541
#
#            cont6     cont7    cont8    cont9   cont10    cont11    cont12  \
# 133017  0.805849  0.638454  0.66201  0.65824  0.67065  0.751690  0.758883
# 8498    0.349350  0.362171  0.39455  0.38249  0.35434  0.260140  0.264760
# 38546   0.204165  0.348605  0.23688  0.22234  0.19782  0.348867  0.341872
# 10917   0.331398  0.361715  0.56600  0.39648  0.32935  0.245410  0.255941
# 83256   0.484775  0.729795  0.35533  0.40657  0.40666  0.468839  0.458493
# ...          ...       ...      ...      ...      ...       ...       ...
# 100201  0.373500  0.381883  0.36083  0.44352  0.45017  0.338312  0.366307
# 24465   0.966438  0.640047  0.58934  0.97621  0.83510  0.895938  0.887214
# 35429   0.314683  0.370419  0.58354  0.46226  0.38016  0.341813  0.352251
# 26602   0.331919  0.336160  0.36083  0.39849  0.39599  0.297750  0.301921
# 158976  0.464835  0.800337  0.70839  0.43111  0.36974  0.569745  0.557380
#
#           cont13    cont14
# 133017  0.743962  0.660295
# 8498    0.327393  0.209840
# 38546   0.268941  0.230744
# 10917   0.295948  0.506150
# 83256   0.304350  0.741741
# ...          ...       ...
# 100201  0.339244  0.383675
# 24465   0.906079  0.686929
# 35429   0.339244  0.692875
# 26602   0.351299  0.349425
# 158976  0.256038  0.208243
#
# [145944 rows x 130 columns]

# %%
X_train = final_pipeline.fit_transform(X_train, y_train)
print("After")
print(X_train)
print(X_train.shape)
# Out:
# After
# [[ 3.40072629e+03  3.79032509e+03  2.90126586e+03 ...  8.42135570e-01
#   -9.08156673e-02  2.35976578e-01]
#  [ 3.40519355e+03  3.80133309e+03  2.90519194e+03 ...  4.43632957e-01
#   -1.83723950e-01  4.49024831e-02]
#  [ 3.40072629e+03  2.45614529e+03  2.90126586e+03 ...  4.53133492e-01
#    3.32069315e-01  1.77241626e-01]
#  ...
#  [ 1.92339003e+03  2.45581165e+03  2.90798737e+03 ... -3.02648357e-01
#   -1.66287840e-01 -1.03185412e-01]
#  [ 3.40072629e+03  2.45614529e+03  2.90126586e+03 ...  2.76361714e-02
#   -1.14070698e-01 -1.66153545e-02]
#  [ 1.91670804e+03  2.45269688e+03  2.90058019e+03 ... -4.50485345e-01
#    1.60024167e-01  6.28488127e-02]]
# (145944, 129)

# %%
print("Before")
print(X_test)
# Out:
# Before
#        cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10  ...     cont5  \
# 117152    A    A    A    A    B    A    A    A    A     A  ...  0.921707
# 18997     B    A    A    B    A    B    A    A    A     A  ...  0.718531
# 36633     A    A    A    B    A    B    A    A    A     A  ...  0.745764
# 57554     A    B    A    A    B    A    A    A    B     A  ...  0.858841
# 96317     A    B    A    A    B    A    A    A    B     A  ...  0.281143
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...       ...
# 117688    A    A    A    A    A    B    A    A    A     A  ...  0.758711
# 44847     A    B    A    A    B    A    A    A    B     A  ...  0.372405
# 180721    B    A    A    A    A    B    A    A    A     A  ...  0.310061
# 14840     A    B    B    A    B    A    A    A    B     B  ...  0.281143
# 24378     A    B    B    A    A    A    A    A    B     A  ...  0.422268
#
#            cont6     cont7    cont8    cont9   cont10    cont11    cont12  \
# 117152  0.369930  0.400333  0.47669  0.31945  0.36458  0.341813  0.335036
# 18997   0.440945  0.374687  0.31796  0.32128  0.44467  0.327915  0.321570
# 36633   0.295245  0.304065  0.41762  0.39648  0.36458  0.245410  0.241676
# 57554   0.625784  0.605869  0.51256  0.42084  0.57172  0.665172  0.651918
# 96317   0.435733  0.680421  0.26847  0.41471  0.47779  0.672085  0.658814
# ...          ...       ...      ...      ...      ...       ...       ...
# 117688  0.201125  0.259395  0.24564  0.30859  0.21983  0.207238  0.204687
# 44847   0.344288  0.356264  0.95332  0.33051  0.31480  0.291268  0.286079
# 180721  0.461326  0.442664  0.28768  0.38249  0.58796  0.359572  0.409777
# 14840   0.748243  0.538694  0.54829  0.50420  0.51111  0.711942  0.698722
# 24378   0.211915  0.309522  0.29758  0.34365  0.30529  0.245410  0.241676
#
#           cont13    cont14
# 117152  0.598688  0.265690
# 18997   0.605077  0.838703
# 36633   0.246011  0.470608
# 57554   0.614594  0.743470
# 96317   0.304350  0.544615
# ...          ...       ...
# 117688  0.357400  0.714903
# 44847   0.486670  0.783888
# 180721  0.642600  0.381560
# 14840   0.709578  0.236621
# 24378   0.222124  0.602207
#
# [48648 rows x 130 columns]

# %%
X_test = final_pipeline.transform(X_test)
print(X_test)
# Out:
# [[ 3.40450155e+03  2.45363036e+03  2.90270113e+03 ... -3.96182679e-02
#   -1.38322659e-01 -2.24431107e-01]
#  [ 1.92118913e+03  2.45363036e+03  2.90270113e+03 ...  2.02457553e-01
#   -7.08670794e-02  2.20722409e-02]
#  [ 3.40450155e+03  2.45363036e+03  2.90270113e+03 ... -6.68829216e-02
#    8.48612884e-02  1.18185560e-01]
#  ...
#  [ 1.92118913e+03  2.45363036e+03  2.90270113e+03 ... -5.26364865e-02
#   -1.25855181e-01 -1.90493802e-01]
#  [ 3.40450155e+03  3.80047903e+03  5.36007393e+03 ...  4.55991958e-01
#   -1.38542066e-01  4.39579952e-01]
#  [ 3.40450155e+03  3.80047903e+03  5.36007393e+03 ...  1.31589521e-01
#    2.39383149e-01  8.54584483e-02]]

# %% [markdown]
# ## (C) Save Train & Test as numpy array for imports

# %%
np.savez_compressed(
    file= os.path.join(PATH, 'code', 'v2', 'Preprocessed_Pipeline_Data'),
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test
)
